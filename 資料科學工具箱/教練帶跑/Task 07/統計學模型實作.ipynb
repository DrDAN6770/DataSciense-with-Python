# %% [markdown]
# <a href="https://colab.research.google.com/github/DrDAN6770/DataSciense-with-Python/blob/main/%E8%B3%87%E6%96%99%E7%A7%91%E5%AD%B8%E5%B7%A5%E5%85%B7%E7%AE%B1/%E6%95%99%E7%B7%B4%E5%B8%B6%E8%B7%91/Task%2007/%E7%B5%B1%E8%A8%88%E5%AD%B8%E6%A8%A1%E5%9E%8B%E5%AF%A6%E4%BD%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 淺談統計學

# %% [markdown]
# 統計學（Statistics）
#
# * 狹義的統計學是指以數字表 示的事實或資料 （data）
# * 廣義的統計學是指蒐集、整 理、表現、分析及解釋資料，並藉科學的方法，在不確定的情況下，由樣本資料所獲得的結果，來推論母體的性質與事實，從而做出適切決策的一門學科
#
# 統計學可以分成「敘述統計」和「推論統計」兩種類型
# * 敘述統計(descriptive statistics) 用於對資料進行整理，總和和呈現的統計方法
# * 推論統計(inferential statistics) 是根據樣本觀察結果對母體進行推論的統計方法

# %% [markdown]
# ## 敘述統計
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 代表「集中趨勢」的平均值、中位數、眾數
#
# 代表「分散趨勢」的最大值/最小值/範圍、四分位差、變異數/標準差

# %% [markdown]
# ## 推論統計

# %% [markdown]
# 根據樣本資料（sample），估計，預測，決定母群體（人口）的特性。因為樣本資料的資訊小於母群體的資訊，這樣的推論無法完全準確。 信心水平（confidence level），顯著性差異（significance level）。推論統計是從已知資料推敲未知資料

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 抽樣會以某種方式抽樣方法從母體中抽出 n 個元素做為樣本，可以分成常見三種
# * 簡單隨機抽樣（Simple random sampling）
# * 分層隨機抽樣（Stratified sampling）
# * 分群隨機抽樣（Cluster sampling）

# %% [markdown]
# ## 估計與假設檢定

# %% [markdown]
# 推論統計是利用樣本統計量及其抽樣分配來對母體參數進行推論以暸解母體的特性，常見有兩種方法：
#
# 	1. 估計 (estimation) ：利用樣本資訊對母群參數做猜測，可以分成「點估計」或「區間估計」
# 		a. 點估計 : 利用樣本的估計量與估計公式求出的是一個統計量，通常是由隨機樣本所推算出來的隨機變數
# 		b. 區間估計 :  用一個區間去估計母體未知參數，這個隨機區間一般稱作區間估計式
# 	2. 假設檢定 (hypothesis testing)：對於母群參數的假設，利用樣本資料推論是否接受或拒絕該假設
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 迴歸分析

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 在 Python 中實現統計學

# %% [markdown]
# ## 基本統計量

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 頻率表
#
#
# ---
# 計算每個值出現的頻率
#
# 其中 column 為要計算頻率的欄位名稱
#
# `df['column'].value_counts()`

# %% [markdown]
# ## 相關係數
#
# ---
# 計算相關係數
#
# `df.corr()`
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 樞紐分析表(pivot table)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# import pandas as pd
#
# # 使用 pivot_table 計算分類變數對目標變數的平均值
# pivot = pd.pivot_table(df, values='目標變數', index='分類變數', aggfunc='mean')
# ```

# %%
import pandas as pd

# 建立 DataFrame
data = {
    '訂單日期': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08', '2022-01-09', '2022-01-10'],
    '產品名稱': ['A產品', 'B產品', 'C產品', 'A產品', 'B產品', 'C產品', 'A產品', 'B產品', 'C產品', 'A產品'],
    '單價': [100, 200, 300, 100, 200, 300, 100, 200, 300, 100],
    '數量': [10, 20, 30, 10, 20, 30, 10, 20, 30, 10],
    '總價': [1000, 4000, 9000, 1000, 4000, 9000, 1000, 4000, 9000, 1000]
}

df = pd.DataFrame(data)
df
# Out:
#          訂單日期 產品名稱   單價  數量    總價
# 0  2022-01-01  A產品  100  10  1000
# 1  2022-01-02  B產品  200  20  4000
# 2  2022-01-03  C產品  300  30  9000
# 3  2022-01-04  A產品  100  10  1000
# 4  2022-01-05  B產品  200  20  4000
# 5  2022-01-06  C產品  300  30  9000
# 6  2022-01-07  A產品  100  10  1000
# 7  2022-01-08  B產品  200  20  4000
# 8  2022-01-09  C產品  300  30  9000
# 9  2022-01-10  A產品  100  10  1000

# %%
# 使用 pivot_table 函數計算每個產品的平均單價和總銷售額
pivot = pd.pivot_table(df, values=['單價', '總價'], index='產品名稱', aggfunc={'單價':'mean', '總價':'sum'})
# 輸出分析結果
pivot
# Out:
#        單價     總價
# 產品名稱
# A產品   100   4000
# B產品   200  12000
# C產品   300  27000

# %% [markdown]
# # 在 Python 中實現推論統計
#
# ---
#
# 如果是推論統計的話，可以試試看「 statemodels 」這個套件。根據官網的介紹，它提供了常見的統計模型，例如估計、檢定和迴歸的方法。我們建議你可以從「 Getting started 」開始，先認識套件的使用流程與第一個 OLS 範例。OLS 全名是 Ordinary Least Squares ，中文稱為最小平方法，是一種統計中擬合數據的方法。
#
# statsmodels 是一個 Python 套件，提供了一系列統計模型和統計測試的工具。它可以用於探索資料、建立模型、進行推論統計和預測分析等多個方面。在這個段落中將介紹如何使用 statsmodels 套件進行推論統計，包括線性回歸分析、假設檢定和ANOVA分析等。

# %% [markdown]
# ## 線性回歸分析

# %%
import pandas as pd
import statsmodels.api as sm

# 建立 DataFrame
data = {
    'x': [1, 2, 3, 4, 5],
    'y': [2, 4, 6, 8, 10]
}

df = pd.DataFrame(data)

# 建立線性回歸模型
model = sm.formula.ols('y ~ x', data=df).fit()

# 輸出回歸結果
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.582e+30
# Date:                Thu, 04 May 2023   Prob (F-statistic):           1.67e-46
# Time:                        20:46:27   Log-Likelihood:                 161.95
# No. Observations:                   5   AIC:                            -319.9
# Df Residuals:                       3   BIC:                            -320.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.109e-15   2.81e-15     -1.107      0.349    -1.2e-14    5.83e-15
# ...

# %%
print(model.params)
# Out:
# Intercept   -3.108624e-15
# x            2.000000e+00
# dtype: float64

# %% [markdown]
# ## 假設檢定
#
# ---
#
# 假設檢定是統計學中常用的一種方法，用於判斷一個假設是否應該被拒絕。在 Python 中，我們可以使用 statsmodels 套件進行假設檢定。以下是一個使用 statsmodels 套件進行假設檢定的例子：

# %%
import pandas as pd
import numpy as np
import statsmodels.stats.api as sms

# 建立 DataFrame
data = {
    'group': ['A'] * 5 + ['B'] * 5,
    'value': [10, 12, 8, 11, 9, 13, 15, 11, 14, 12]
}

df = pd.DataFrame(data)

# 進行 t 檢定
result = sms.ttest_ind(df[df['group'] == 'A']['value'], df[df['group'] == 'B']['value'])

# 輸出結果
print(result)
# Out:
# (-3.0, 0.017071681233782634, 8.0)

# %% [markdown]
# ```
# 上面的輸出結果中，第一個值表示 t 統計量，第二個值表示對應的雙尾P值，第三個值表示樣本大小
# 	• -3 : 代表A平均小於B平均
# 	• 0.017 : 雙尾p值< 0.05 表示原H0(A平均= B平均)不太成立，A平均不等於B平均，差異越明顯
# 	• 8 : 自由度，在t檢定中判斷p值得一個參數，A樣本數+B樣本數-2 = 5 + 5 - 2 = 8
# ```

# %% [markdown]
# ## ANOVA 分析
#
# ---
#
# ANOVA（Analysis of Variance）分析是統計學中常用的一種方法，用於比較多個樣本組之間的差異。在 Python 中，我們可以使用 statsmodels 套件進行 ANOVA 分析。以下是一個使用 statsmodels 套件進行 ANOVA 分析的例子：

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 建立 DataFrame
data = {
    'group': ['A'] * 5 + ['B'] * 5 + ['C'] * 5,
    'value': [10, 12, 8, 11, 9, 13, 15, 11, 14, 12, 18, 16, 17, 19, 15]
}

df = pd.DataFrame(data)

# 進行 ANOVA 分析
model = ols('value ~ group', data=df).fit()
anova_table = sm.stats.anova_lm(model)
print(anova_table)
# Out:
#             df      sum_sq    mean_sq          F    PR(>F)
# group      2.0  123.333333  61.666667  24.666667  0.000056
# Residual  12.0   30.000000   2.500000        NaN       NaN

# %% [markdown]
# ```
# df 表示自由度，sum_sq 表示總平方和，mean_sq 表示平均平方和，F 表示F統計量，PR(>F) 表示對應的雙尾P值
# ```

# %% [markdown]
# ### 案例1
#
# ---
# 假設我們有一個醫學研究想要比較三種藥物對疾病治療效果的差異。我們隨機挑選了30位患者，將其隨機分成三組，每組10人，分別給予不同藥物的治療。治療結束後，我們記錄每位患者的治療效果，即治療後的疾病症狀程度。現在，我們想要使用ANOVA分析來比較三種藥物的治療效果是否存在差異。

# %%
# 創建數據
data = {'group': ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',
                  'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
                  'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C'],
        'effect': [3.1, 3.3, 3.2, 2.8, 2.9, 3.5, 3.4, 2.9, 3.2, 3.0,
                   2.8, 2.7, 2.5, 2.4, 2.9, 2.6, 2.5, 2.7, 2.8, 2.6,
                   1.9, 2.1, 1.8, 1.7, 2.0, 2.2, 2.1, 1.9, 1.8, 1.7]}

df = pd.DataFrame(data)

# %%
from statsmodels.formula.api import ols

# 創建線性回歸模型
model = ols('effect ~ group', data=df).fit()

# %%
from statsmodels.stats.anova import anova_lm

# 進行ANOVA分析
anova_results = anova_lm(model)

# 輸出結果
print(anova_results)
# Out:
#             df    sum_sq   mean_sq           F        PR(>F)
# group      2.0  7.424667  3.712333  102.070265  2.576816e-13
# Residual  27.0  0.982000  0.036370         NaN           NaN

# %% [markdown]
# ```
# 從上面的結果可以看出，group 的 PR(>F) 值非常小（小於 0.05），意味著三種藥物的治療效果存在顯著差異。
# 因此，我們可以得出結論：三種藥物的治療效果不同。
# ```

# %% [markdown]
# ### 案例2
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

data = {
    'batch': ['A'] * 5 + ['B'] * 5 + ['C'] * 5 + ['D'] * 5 + ['E'] * 5,
    'value': [29.39, 31.51, 30.88, 27.63, 28.85,
              30.63, 32.10, 30.11, 29.63, 29.68,
              27.16, 26.63, 25.31, 27.66, 27.10,
              31.03, 30.98, 28.95, 31.45, 29.70,
              29.67, 29.32, 26.87, 31.59, 29.41]
}

df = pd.DataFrame(data)

# 進行 ANOVA 分析
model = ols('value ~ batch', data=df).fit()
anova_table = sm.stats.anova_lm(model)
print(anova_table)
# Out:
#             df     sum_sq    mean_sq         F    PR(>F)
# batch      4.0  45.256376  11.314094  6.899486  0.001166
# Residual  20.0  32.796920   1.639846       NaN       NaN
